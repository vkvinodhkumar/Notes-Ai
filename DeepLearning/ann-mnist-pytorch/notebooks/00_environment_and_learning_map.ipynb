# %% [markdown]
# # 00 — Environment, Learning Map, and End-to-End ANN Contract (PyTorch)
#
#
# > **Learning contract.** Every code cell is preceded by an explanation of what the code does, why the operation exists mathematically, what tensor/array shapes are expected, and what production or business failure it prevents. Run the notebooks in numerical order in a fresh Conda environment.
#
#
# This course treats an artificial neural network as a complete engineering lifecycle, not merely a function that maps pixels to labels. You will follow MNIST through provenance, data quality, train/validation/test separation, preprocessing, forward propagation, loss, backpropagation, optimization, validation, final test, serialization, inference, performance, monitoring, drift, retraining, and business decisioning.
#
# ## Lifecycle
# `problem → data → split → preprocess → batch → architecture → initialize → forward → loss → backward → optimize → validate → test → infer → monitor → retrain → business action`
#
# **Framework role.** PyTorch is an implementation language for the mathematics; it is not the explanation. Every abstraction is tied back to matrix operations and gradients.

# %% [markdown]
# ## Code walkthrough — verify the runtime before learning
# The first executable cell prints the exact Python and numerical-library versions. In production, an unrecorded environment is a reproducibility defect: identical source code can behave differently when dependency versions change.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

torch.manual_seed(42)
import sys

print("python", sys.version.split()[0])
print("numpy", np.__version__)
print("torch", torch.__version__)
# Out:
# python 3.11.16
# numpy 1.26.4
# torch 2.5.1+cpu

# %% [markdown]
# ## What success means
# By the end, you should be able to explain the ANN without framework vocabulary: what each matrix contains, how shapes flow through the network, why loss creates gradients, how validation prevents test leakage, how internal representations move during learning, and what must be monitored after deployment.
